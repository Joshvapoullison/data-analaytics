# %%
import numpy as np
import pandas as pd
d = {
    'A': [1,2, np.nan],
    'B':[5, np.nan, np.nan],
    'C':[1,2,3]
}
df=pd.DataFrame(d)

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(axis = 0)
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(axis = 1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.fillna(value='wow')
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  wow  2
# 2  wow  wow  3

# %%
df=pd.DataFrame(d)

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
a = df['A'].fillna(value = df['A'].mean())

# %%
a
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
import numpy as np
import pandas as pd
data = {
    'Company':['Google', 'Google', 'MSFT', 'FB','FB','IBM'],
    'Person': ['Sam','Nihad','Any','Van','Rakib','Ovi'],
    'Sales': [200, 120, 340, 124, 243, 350]
}
df=pd.DataFrame(data)

# %%
df
# Out:
#   Company Person  Sales
# 0  Google    Sam    200
# 1  Google  Nihad    120
# 2    MSFT    Any    340
# 3      FB    Van    124
# 4      FB  Rakib    243
# 5     IBM    Ovi    350

# %%
bycomp=df.groupby('Company')
bycomp['Company'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File D:\Users\JOSHUVA PAUL LINSON\OneDrive\Lib\site-packages\pandas\core\groupby\groupby.py:1944, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1943 try:
# -> 1944     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1945 except Exception as err:
#
# File D:\Users\JOSHUVA PAUL LINSON\OneDrive\Lib\site-packages\pandas\core\groupby\ops.py:873, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     871     preserve_dtype = True
# --> 873 result = self._aggregate_series_pure_python(obj, func)
#     875 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File D:\Users\JOSHUVA PAUL LINSON\OneDrive\Lib\site-packages\pandas\core\groupby\ops.py:894, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     893 for i, group in enumerate(splitter):
# ...

# %%
bycomp.sum()
# Out:
#            Person  Sales
# Company
# FB       VanRakib    367
# Google   SamNihad    320
# IBM           Ovi    350
# MSFT          Any    340

# %%
df
# Out:
#   Company Person  Sales
# 0  Google    Sam    200
# 1  Google  Nihad    120
# 2    MSFT    Any    340
# 3      FB    Van    124
# 4      FB  Rakib    243
# 5     IBM    Ovi    350

# %%
bycomp.std()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 bycomp.std()
#
# File D:\Users\JOSHUVA PAUL LINSON\OneDrive\Lib\site-packages\pandas\core\groupby\groupby.py:2648, in GroupBy.std(self, ddof, engine, engine_kwargs, numeric_only)
#    2638     return np.sqrt(
#    2639         self._numba_agg_general(
#    2640             grouped_var,
#    (...)   2645         )
#    2646     )
#    2647 else:
# -> 2648     return self._cython_agg_general(
#    2649         "std",
#    2650         alt=lambda x: Series(x, copy=False).std(ddof=ddof),
#    2651         numeric_only=numeric_only,
#    2652         ddof=ddof,
#    2653     )
#
# File D:\Users\JOSHUVA PAUL LINSON\OneDrive\Lib\site-packages\pandas\core\groupby\groupby.py:2005, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
# ...

# %%
df.groupby('Company').count()
# Out:
#          Person  Sales
# Company
# FB            2      2
# Google        2      2
# IBM           1      1
# MSFT          1      1

# %%
df
# Out:
#   Company Person  Sales
# 0  Google    Sam    200
# 1  Google  Nihad    120
# 2    MSFT    Any    340
# 3      FB    Van    124
# 4      FB  Rakib    243
# 5     IBM    Ovi    350

# %%
df.groupby('Company').describe()
# Out:
#         Sales
#         count   mean        std    min     25%    50%     75%    max
# Company
# FB        2.0  183.5  84.145707  124.0  153.75  183.5  213.25  243.0
# Google    2.0  160.0  56.568542  120.0  140.00  160.0  180.00  200.0
# IBM       1.0  350.0        NaN  350.0  350.00  350.0  350.00  350.0
# MSFT      1.0  340.0        NaN  340.0  340.00  340.0  340.00  340.0

# %%
df1=pd.DataFrame(np.random.randint(1,20,size=(4,3)),[1,2,3,4],['w','o','w'])

# %%
df1
# Out:
#     w   o   w
# 1   3   5  17
# 2  13  17  12
# 3   3  14   5
# 4  11  17   6

# %%
df2=pd.DataFrame(np.random.randint(20,40,size=(4,3)),[5,6,7,8],['F','I','V'])

# %%
df2
# Out:
#     F   I   V
# 5  38  37  26
# 6  39  37  22
# 7  38  20  27
# 8  36  24  27

# %%
df3 = pd.DataFrame(np.random.randint(40,60, size = (4, 3)), [9,10,11,12], ['W', 'X', 'Y'])

# %%
df3
# Out:
#      W   X   Y
# 9   42  55  41
# 10  54  41  54
# 11  57  46  54
# 12  46  41  59

# %%
frame=[df1,df2,df3]
frame
# Out:
# [    w   o   w
#  1   3   5  17
#  2  13  17  12
#  3   3  14   5
#  4  11  17   6,
#      F   I   V
#  5  38  37  26
#  6  39  37  22
#  7  38  20  27
#  8  36  24  27,
#       W   X   Y
#  9   42  55  41
#  10  54  41  54
#  11  57  46  54
#  12  46  41  59]

# %%
pd.concat(frame)
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 pd.concat(frame)
#
# File D:\Users\JOSHUVA PAUL LINSON\OneDrive\Lib\site-packages\pandas\core\reshape\concat.py:395, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     380     copy = False
#     382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#    (...)    392     sort=sort,
#     393 )
# --> 395 return op.get_result()
#
# File D:\Users\JOSHUVA PAUL LINSON\OneDrive\Lib\site-packages\pandas\core\reshape\concat.py:680, in _Concatenator.get_result(self)
#     678         obj_labels = obj.axes[1 - ax]
#     679         if not new_labels.equals(obj_labels):
# --> 680             indexers[ax] = obj_labels.get_indexer(new_labels)
#     682     mgrs_indexers.append((obj._mgr, indexers))
#     684 new_data = concatenate_managers(
# ...

# %%
pd.concat(frame,axis=1)
# Out:
#        w     o     w     F     I     V     W     X     Y
# 1    3.0   5.0  17.0   NaN   NaN   NaN   NaN   NaN   NaN
# 2   13.0  17.0  12.0   NaN   NaN   NaN   NaN   NaN   NaN
# 3    3.0  14.0   5.0   NaN   NaN   NaN   NaN   NaN   NaN
# 4   11.0  17.0   6.0   NaN   NaN   NaN   NaN   NaN   NaN
# 5    NaN   NaN   NaN  38.0  37.0  26.0   NaN   NaN   NaN
# 6    NaN   NaN   NaN  39.0  37.0  22.0   NaN   NaN   NaN
# 7    NaN   NaN   NaN  38.0  20.0  27.0   NaN   NaN   NaN
# 8    NaN   NaN   NaN  36.0  24.0  27.0   NaN   NaN   NaN
# 9    NaN   NaN   NaN   NaN   NaN   NaN  42.0  55.0  41.0
# 10   NaN   NaN   NaN   NaN   NaN   NaN  54.0  41.0  54.0
# 11   NaN   NaN   NaN   NaN   NaN   NaN  57.0  46.0  54.0
# 12   NaN   NaN   NaN   NaN   NaN   NaN  46.0  41.0  59.0

# %%
left = {
    'key':['k0','k1','k2','k3'],
    'A':[10,20,30,40],
    'B':[1,2,3,4]
}

# %%
right = {
    'key':['k0','k1','k2','k3'],
    'C':[100,200,300,400],
    'D':[11,12,13,14]
}

# %%
left=pd.DataFrame(left)

# %%
right=pd.DataFrame(right)

# %%
left
# Out:
#   key   A  B
# 0  k0  10  1
# 1  k1  20  2
# 2  k2  30  3
# 3  k3  40  4

# %%
right
# Out:
#   key    C   D
# 0  k0  100  11
# 1  k1  200  12
# 2  k2  300  13
# 3  k3  400  14

# %%
pd.merge(left,right, on='key')
# Out:
#   key   A  B    C   D
# 0  k0  10  1  100  11
# 1  k1  20  2  200  12
# 2  k2  30  3  300  13
# 3  k3  40  4  400  14

# %%
left = {
    'A':['A0','A1','A2'],
    'B':['B0','B1','B2']
}

# %%
right = {
    'C':['C0','C2','C3'],
    'D':['D0','D2','D3']
}

# %%
left=pd.DataFrame(left,index=['k0','k1','k2'])

# %%
right=pd.DataFrame(right,index=['k0','k1','k2'])

# %%
left
# Out:
#      A   B
# k0  A0  B0
# k1  A1  B1
# k2  A2  B2

# %%
right
# Out:
#      C   D
# k0  C0  D0
# k1  C2  D2
# k2  C3  D3

# %%
right.join(left,how='inner')
# Out:
#      C   D   A   B
# k0  C0  D0  A0  B0
# k1  C2  D2  A1  B1
# k2  C3  D3  A2  B2

# %%
df = pd.DataFrame({
    'col1':[444,555,666,444],
    'col2':[1,2,3,4],
    'col3':['abc','def','ghi','xyz']
})

# %%
df
# Out:
#    col1  col2 col3
# 0   444     1  abc
# 1   555     2  def
# 2   666     3  ghi
# 3   444     4  xyz

# %%
df['col1'].unique()
# Out:
# array([444, 555, 666])

# %%
df['col1'].value_counts()
# Out:
# col1
# 444    2
# 555    1
# 666    1
# Name: count, dtype: int64

# %%
df['col1'].nunique()
# Out:
# 3

# %%
def times2(x):
    return 2*x

# %%
df['col2'].apply(times2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col2, dtype: int64

# %%
 df['col2'].apply(lambda x:x**2)
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# Name: col2, dtype: int64

# %%
df = pd.read_excel('SampleData.xlsx', sheet_name = 'SalesOrders')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 df = pd.read_excel('SampleData.xlsx', sheet_name = 'SalesOrders')
#
# File D:\Users\JOSHUVA PAUL LINSON\OneDrive\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
# ...
