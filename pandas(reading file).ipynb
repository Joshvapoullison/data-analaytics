# %%
import numpy as np
import pandas as pd
df = pd.read_csv(r"C:\Users\JOSHUVA PAUL LINSON\Downloads\toptech\task1\sales.csv")

# %%
df
# Out:
#     Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0      1.0  CA-2017-152156  08-11-2017  11-11-2017    Second Class
# 1      2.0  CA-2017-152156  08-11-2017  11-11-2017    Second Class
# 2      3.0  CA-2017-138688  12-06-2017  16-06-2017    Second Class
# 3      4.0  US-2016-108966  11-10-2016  18-10-2016  Standard Class
# 4      5.0  US-2016-108966  11-10-2016  18-10-2016  Standard Class
# 5      6.0  CA-2015-115812  09-06-2015  14-06-2015  Standard Class
# 6      7.0  CA-2015-115812  09-06-2015  14-06-2015  Standard Class
# 7      8.0  CA-2015-115812  09-06-2015  14-06-2015  Standard Class
# 8      9.0  CA-2015-115812  09-06-2015  14-06-2015  Standard Class
# 9     10.0  CA-2015-115812  09-06-2015  14-06-2015  Standard Class
# 10     NaN             NaN         NaN         NaN             NaN
# 11     NaN             NaN         NaN         NaN             NaN
# 12     NaN             NaN         NaN         NaN             NaN
# ...

# %%
df.head(10)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     1.0  CA-2017-152156  08-11-2017  11-11-2017    Second Class    CG-12520
# 1     2.0  CA-2017-152156  08-11-2017  11-11-2017    Second Class    CG-12520
# 2     3.0  CA-2017-138688  12-06-2017  16-06-2017    Second Class    DV-13045
# 3     4.0  US-2016-108966  11-10-2016  18-10-2016  Standard Class    SO-20335
# 4     5.0  US-2016-108966  11-10-2016  18-10-2016  Standard Class    SO-20335
# 5     6.0  CA-2015-115812  09-06-2015  14-06-2015  Standard Class    BH-11710
# 6     7.0  CA-2015-115812  09-06-2015  14-06-2015  Standard Class    BH-11710
# 7     8.0  CA-2015-115812  09-06-2015  14-06-2015  Standard Class    BH-11710
# 8     9.0  CA-2015-115812  09-06-2015  14-06-2015  Standard Class    BH-11710
# 9    10.0  CA-2015-115812  09-06-2015  14-06-2015  Standard Class    BH-11710
#
#      Customer Name    Segment       Product ID         Category Sub-Category  \
# ...

# %%
df.tail()
# Out:
#     Row ID Order ID Order Date Ship Date Ship Mode Customer ID Customer Name  \
# 11     NaN      NaN        NaN       NaN       NaN         NaN           NaN
# 12     NaN      NaN        NaN       NaN       NaN         NaN           NaN
# 13     NaN      NaN        NaN       NaN       NaN         NaN           NaN
# 14     NaN      NaN        NaN       NaN       NaN         NaN           NaN
# 15     NaN      NaN        NaN       NaN       NaN         NaN           NaN
#
#    Segment Product ID Category Sub-Category Product Name  Sales
# 11     NaN        NaN      NaN          NaN          NaN    NaN
# 12     NaN        NaN      NaN          NaN          NaN    NaN
# 13     NaN        NaN      NaN          NaN          NaN    NaN
# 14     NaN        NaN      NaN          NaN          NaN    NaN
# 15     NaN        NaN      NaN          NaN                 NaN

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales'],
#       dtype='object')

# %%
df.columns.to_list()
# Out:
# ['Row ID',
#  'Order ID',
#  'Order Date',
#  'Ship Date',
#  'Ship Mode',
#  'Customer ID',
#  'Customer Name',
#  'Segment',
#  'Product ID',
#  'Category',
#  'Sub-Category',
#  'Product Name',
#  'Sales']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         10 non-null     float64
#  1   Order ID       10 non-null     object
#  2   Order Date     10 non-null     object
#  3   Ship Date      10 non-null     object
#  4   Ship Mode      10 non-null     object
#  5   Customer ID    10 non-null     object
#  6   Customer Name  10 non-null     object
#  7   Segment        10 non-null     object
#  8   Product ID     10 non-null     object
#  9   Category       10 non-null     object
#  10  Sub-Category   10 non-null     object
#  11  Product Name   11 non-null     object
#  12  Sales          10 non-null     float64
# dtypes: float64(2), object(11)
# memory usage: 1.8+ KB

# %%
df.nunique()
# Out:
# Row ID           10
# Order ID          4
# Order Date        4
# Ship Date         4
# Ship Mode         2
# Customer ID       4
# Customer Name     4
# Segment           2
# Product ID       10
# Category          3
# Sub-Category     10
# Product Name     11
# Sales            10
# dtype: int64

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     1.0  CA-2017-152156  08-11-2017  11-11-2017    Second Class    CG-12520
# 1     2.0  CA-2017-152156  08-11-2017  11-11-2017    Second Class    CG-12520
# 2     3.0  CA-2017-138688  12-06-2017  16-06-2017    Second Class    DV-13045
# 3     4.0  US-2016-108966  11-10-2016  18-10-2016  Standard Class    SO-20335
# 4     5.0  US-2016-108966  11-10-2016  18-10-2016  Standard Class    SO-20335
#
#      Customer Name    Segment       Product ID         Category Sub-Category  \
# 0      Claire Gute   Consumer  FUR-BO-10001798        Furniture    Bookcases
# 1      Claire Gute   Consumer  FUR-CH-10000454        Furniture       Chairs
# 2  Darrin Van Huff  Corporate  OFF-LA-10000240  Office Supplies       Labels
# 3   Sean O'Donnell   Consumer  FUR-TA-10000577        Furniture       Tables
# 4   Sean O'Donnell   Consumer  OFF-ST-10000760  Office Supplies      Storage
#
# ...
