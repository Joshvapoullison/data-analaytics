# %%
import numpy as np
a=np.array([1,2,5,4])
b=np.array([[1,2],[3,4]])
c=np.array([[5,6],[7,8]])
r=np.arange(0,10,2)
print(r)
# Out:
# [0 2 4 6 8]

# %%
l=np.linspace(0,1,5)
print(l)
# Out:
# [0.   0.25 0.5  0.75 1.  ]

# %%
c=[1,23,4,5,6,7,8,9,99,8]
print(c[0:4])
# Out:
# [1, 23, 4, 5]

# %%
print(a+5)
# Out:
# [ 6  7 10  9]

# %%
print(a*2)
# Out:
# [ 2  4 10  8]

# %%
print(b+c[0])
# Out:
# [[ 6  8]
#  [ 8 10]]

# %%
print(np.dot(b,b))
# Out:
# [[ 7 10]
#  [15 22]]

# %%
print(np.sum(a))
# Out:
# 12

# %%
print(np.mean(a))
print(np.max(a))
print(np.sqrt(a))
# Out:
# 3.0
# 5
# [1.         1.41421356 2.23606798 2.        ]

# %%
x=np.arange(6).reshape(2,3)
print(x)
# Out:
# [[0 1 2]
#  [3 4 5]]

# %%
print(x.T)
# Out:
# [[0 3]
#  [1 4]
#  [2 5]]

# %%
random_arr=np.random.rand(2,3)
ran_int=np.random.randint(1,10,5)
print(random_arr)
print(ran_int)
# Out:
# [[0.98091733 0.31700748 0.2086138 ]
#  [0.47605563 0.63985063 0.17184013]]
# [4 2 9 1 5]

# %%
np.save('array_file.npy',a)
loaded=np.load('array_file.npy')

# %%
m=np.array([[1,2],[3,4]])
print(np.linalg.inv(m))
print(np.linalg.det(m))
# Out:
# [[-2.   1. ]
#  [ 1.5 -0.5]]
# -2.0000000000000004

# %%
arr=np.array([1,3,2,3])
print(np.unique(arr))
print(np.sort(arr))
print(np.where(arr>2))
# Out:
# [1 2 3]
# [1 2 3 3]
# (array([1, 3]),)
